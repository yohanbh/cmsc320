# %% [markdown]
# # **HOMEWORK 2...?** 🕵
# ## **DUE: *JUNE 17, 2026 @ 11:59 PM***
# ## **24-HR LATE DUE DATE W/ A 15% PENALTY: *JUNE 18, 2026 @ 11:59 PM***
#
# ### **DO NOT REMOVE ANY PART OF ANY QUESTION OR YOU WILL LOSE CREDIT**
# ### *No hardcoding any part of any question*  😋🪄🧌
# ### **REMEMBER TO SHOW ALL CODE OUTPUT (NO CREDIT OTHERWISE)**
# ### **Reminder: Please make sure your code runs before submitting your work. Code sections that do not run will receive 0 credit; no partial credit will be given. This is VERY important in real project development.**

# %% [markdown]
# ---
# ---
# **DISCLAIMER: This is a fictional story, not a real incident! We created this story only for data exploration purposes.**
#
# ---
# ---
#
# **Campus Police Department**
#
# Incident Report
#
# ---
#
# **Incident Date:** February 27, 2026
#
# **Location of Incident:** 2nd Floor, Iribe Building
#
# **Item Left at the Scene:** Red ticket for Zichao's Magic Show
#
# **Case Number:** 2026-IRB-0027
#
# ---
# **Victim Information:**
#
# **Name:** Dr. Fardina Alam
#
# **Affiliation:** University of Maryland, College Park
#
# **Position:** Professor
#
# **Contact Information:** fardina@umd.edu
#
# ---
#
# **Incident Description:**
#
# On the evening of February 27, 2026, an unknown individual unlawfully entered Dr. Fardina's room on the 2nd floor of Iribe and stole a set of markers. The stolen items were a set of limited-edition markers that Dr. Fardina had spent years collecting. At the scene of the crime, a red entry ticket for "Zichao's Magic Show" was found on the floor near Dr. Fardina's desk.

# %%
# We import all essential libraries for this homework.
# If you want to add additional libraries, you can add them here!
import pandas as pd
from datetime import datetime
import string

# %% [markdown]
# ## YOUR TASK 🔎:
#
# In this assignment, you are tasked with solving the mystery of Dr. Fardina's stolen markers and finding the culprit.
#
# * To accomplish this, you will be provided with **4 datasets** containing key information related to the incident. The names of the datasets are listed below:
#
#  - Profiles
#  - Witnesses
#  - Zichao's Magic Show
#  - Interrogation Statements
#
#
#
# * Your goal is to analyze these datasets to uncover the clues and evidence that will lead you to the thief.
#
# **Be careful when following the instructions, as mistakes may cause you to lose points. :(**
#
# Take a moment to look at all the datasets below:
#
# ---
#
# **Profiles:**
#
# This dataset contains information about all the potential people who could have committed the crime. General information about each person is as follows:
# - **ID:** A **unique** identification number for each person
# - **Name:** The name of the person
# - **Birthday:** The birthday of the person
# - **Location_during_crime:** The location of the person during the crime
# - **Eye_Color:** The eye color of the person
# - **Skin_Color:** The skin color of the person
# - **Hair_Color:** The hair color of the person
# - **Height:** The height of the person in cm
#
# **Witnesses:**
#
# This dataset contains a statement from everyone in `Profiles` about suspicious things they saw around the time of the crime. The information in this dataset is as follows:
# - **ID:** A **unique** identification number for each person
# - **Statement:** A statement from the person about suspicious activity around the time of the crime
#
# **Zichao's Magic Show:**
#
# This dataset contains everyone who purchased a ticket for the show. **NOTE** that not everyone in `Profiles` purchased a ticket for this show. The information contained in this dataset is as follows:
# - **ID:** A **unique** identification number for each person
# - **Ticket_Number:** A **unique** number that serves as an identification number for the purchased ticket
#
# **Interrogation Statements:**
#
# This dataset contains a statement from each person after they have been interrogated. **NOTE:** Assume that each statement is ***100% true*** and that ***there are people in this dataset who are not in the `Profiles` dataset***.
# The information contained in this dataset is as follows:
#
# - **Name:** The name of the person being interrogated
# - **Statement:** A statement the person gives after being interrogated
#
# ---

# %% [markdown]
# ## Q1) Let's begin by observing the Profiles dataset (10 PTS Total)

# %% [markdown]
# **TASK 1.1 (1 Point):** In the code cell below, load the "Profiles" dataset into a variable called **profiles_df** and display it.

# %%
profiles_df = pd.read_csv("Profiles.csv")
profiles_df
# Out:
#        ID              Name    Birthday Location_during_crime Eye_Color  \
# 0    P299       Marco Rossi  1969/07/10          fourth floor       red
# 1    P086       Aarav Patel  1979/03/10          second floor    indigo
# 2    P022            Li Wei  1990/10/08          fourth floor      blue
# 3    P003     Haruto Tanaka  1996/27/10                 lobby     green
# 4    P036      Kwame Mensah  1991/26/02          fourth floor      blue
# ..    ...               ...         ...                   ...       ...
# 343  P126       Andrew Choe  1988/03/01                   NaN    violet
# 344  P203     Krish Thakker  1965/26/09           third floor    yellow
# 345  P273     Jeonghan Yoon  2003/12/07          fourth floor      blue
# 346  P290  Ananya Malipeddi  10/03/1994           third floor       NaN
# 347  P233         Ifra Syed  06/27/1982          second floor       red
#
#     Skin_Color Hair_Color  Height
# 0       indigo     orange     191
# ...

# %% [markdown]
# **TASK 1.2 (1 Point):** Next, display the number of rows and columns in the "Profiles" dataset.

# %%
profiles_df.shape
# Out:
# (348, 8)

# %% [markdown]
# **TASK 1.3 (1 Point):** Next, display the names of the columns in the "Profiles" dataset.

# %%
profiles_df.columns
# Out:
# Index(['ID', 'Name', 'Birthday', 'Location_during_crime', 'Eye_Color',
#        'Skin_Color', 'Hair_Color', 'Height'],
#       dtype='object')

# %% [markdown]
# **TASK 1.4 (1 Point):** Now, display the data types of the columns in the "Profiles" dataset.

# %%
profiles_df.dtypes
# Out:
# ID                       object
# Name                     object
# Birthday                 object
# Location_during_crime    object
# Eye_Color                object
# Skin_Color               object
# Hair_Color               object
# Height                    int64
# dtype: object

# %% [markdown]
# **TASK 1.5 (2 Points):** Use the `count()` function on this dataset, assign the result to a variable called **info**, and then display it.
#
# Write any **potential problems** that you see with the dataset after observing the output of the `count()` function:

# %%
info = profiles_df.count()
info
# Out:
# ID                       348
# Name                     348
# Birthday                 348
# Location_during_crime    280
# Eye_Color                280
# Skin_Color               348
# Hair_Color               348
# Height                   348
# dtype: int64

# %% [markdown]
# **<font color='red'>Write your observations here:</font>**
#
# The location_during_crime and eye_colour columns each have only 280 non-null values, while the dataset has 348 rows. This means that both columns are missing 68 values. These missing values may need to be handled before analyzing the data.

# %% [markdown]
# **TASK 1.6 (4 Points):**
#
# Look back at the "Profiles" dataset. Using Pandas functions other than `count()`, **can you spot another potential problem with the dataset?**

# %%
print("Total IDs:", profiles_df["ID"].size)
print("Unique IDs:", profiles_df["ID"].nunique())
# Out:
# Total IDs: 348
# Unique IDs: 300

# %% [markdown]
# **<font color='red'>Write your observations here:</font>**
#
# There are 48 duplicate IDs even though the IDs should be unique for each person.

# %% [markdown]
# ## Q2) Cleaning the Dataset (25 PTS Total)

# %% [markdown]
# **TASK 2.1 (10 Points):** Let's begin by fixing the `Birthday` column. You may notice that the dates are in inconsistent formats!
#
# - Pandas internally represents dates in `datetime64` format, which is a form of ISO 8601. Basically, dates are represented as `yyyy-mm-dd`.
#
#
# - Fix all the dates in the `Birthday` column.
# - Display the "Profiles" DataFrame after you are done.
# - Note that the dates are in only **2 formats**: either **yyyy/dd/mm** or **mm/dd/yyyy**.
# - You want to represent them as **yyyy-mm-dd**.
#
# - **EXAMPLE**: In the “Profiles” dataset, dates like *2000/10/12* and *10/12/2000* follow different formats—one as *December 10, 2000*, and the other as *October 12, 2000*. We aim to standardize them to *2000-12-10* and *2000-10-12*, respectively.
#
# **HINT:** Some `datetime` functions might make things easier.
# - https://www.geeksforgeeks.org/python-pandas-to_datetime/
# - https://www.programiz.com/python-programming/datetime/strftime

# %%
def fix_date(date):
    if len(date.split("/")[0]) == 4:
        return datetime.strptime(date, "%Y/%d/%m")
    else:
        return datetime.strptime(date, "%m/%d/%Y")
    
profiles_df["Birthday"] = profiles_df["Birthday"].apply(fix_date)

profiles_df
# Out:
#        ID              Name   Birthday Location_during_crime Eye_Color  \
# 0    P299       Marco Rossi 1969-10-07          fourth floor       red
# 1    P086       Aarav Patel 1979-10-03          second floor    indigo
# 2    P022            Li Wei 1990-08-10          fourth floor      blue
# 3    P003     Haruto Tanaka 1996-10-27                 lobby     green
# 4    P036      Kwame Mensah 1991-02-26          fourth floor      blue
# ..    ...               ...        ...                   ...       ...
# 343  P126       Andrew Choe 1988-01-03                   NaN    violet
# 344  P203     Krish Thakker 1965-09-26           third floor    yellow
# 345  P273     Jeonghan Yoon 2003-07-12          fourth floor      blue
# 346  P290  Ananya Malipeddi 1994-10-03           third floor       NaN
# 347  P233         Ifra Syed 1982-06-27          second floor       red
#
#     Skin_Color Hair_Color  Height
# 0       indigo     orange     191
# 1       indigo      green     198
# ...

# %% [markdown]
# **TASK 2.2 (5 Points):** Now that we have cleaned up the `Birthday` column, let's find the age of each person. Create a new column called `Age` that displays the person's age **on the day of the crime.** Once you are done, display the "Profiles" DataFrame.

# %%
crime_date = pd.Timestamp("2026-02-27")

profiles_df["Age"] = (
    crime_date.year
    - profiles_df["Birthday"].dt.year
    - (
        (profiles_df["Birthday"].dt.month > crime_date.month)
        | (
            (profiles_df["Birthday"].dt.month == crime_date.month)
            & (profiles_df["Birthday"].dt.day > crime_date.day)
        )
    )
)

profiles_df
# Out:
#        ID              Name   Birthday Location_during_crime Eye_Color  \
# 0    P299       Marco Rossi 1969-10-07          fourth floor       red
# 1    P086       Aarav Patel 1979-10-03          second floor    indigo
# 2    P022            Li Wei 1990-08-10          fourth floor      blue
# 3    P003     Haruto Tanaka 1996-10-27                 lobby     green
# 4    P036      Kwame Mensah 1991-02-26          fourth floor      blue
# ..    ...               ...        ...                   ...       ...
# 343  P126       Andrew Choe 1988-01-03                   NaN    violet
# 344  P203     Krish Thakker 1965-09-26           third floor    yellow
# 345  P273     Jeonghan Yoon 2003-07-12          fourth floor      blue
# 346  P290  Ananya Malipeddi 1994-10-03           third floor       NaN
# 347  P233         Ifra Syed 1982-06-27          second floor       red
#
#     Skin_Color Hair_Color  Height  Age
# 0       indigo     orange     191   56
# ...

# %% [markdown]
# **TASK 2.3 (10 Points):** Now that we have created the `Age` column, let's clean the `Eye_Color` column.
#
# ***Please read the directions carefully:***
#
#
# - To fill in the missing eye colors, we want to find the **most common eye color** among people who have the **same hair and skin color**.
# - For instance, if we want to find the eye color of someone who has yellow hair and violet skin:
#  - We would first find everyone who has the same hair and skin color; in this case, that would be yellow hair and violet skin.
#  - Then we would find the most common eye color among them.
#  - We then replace the missing eye color with the eye color that is most common among people with the same hair and skin color.
# - Watch out for redundant data!
#
# - ***NOTE: If you find multiple modes, choose the color that appears first in alphabetical order.***
#
#  When you finish filling in the missing eye colors, please **display `profiles_df`**.

# %%
most_common_eyecolor = (
    profiles_df.groupby(["Hair_Color", "Skin_Color"])["Eye_Color"].transform(lambda colors: sorted(colors.dropna().mode())[0])
)

profiles_df["Eye_Color"] = profiles_df["Eye_Color"].fillna(most_common_eyecolor)

profiles_df
# Out:
#        ID              Name   Birthday Location_during_crime Eye_Color  \
# 0    P299       Marco Rossi 1969-10-07          fourth floor       red
# 1    P086       Aarav Patel 1979-10-03          second floor    indigo
# 2    P022            Li Wei 1990-08-10          fourth floor      blue
# 3    P003     Haruto Tanaka 1996-10-27                 lobby     green
# 4    P036      Kwame Mensah 1991-02-26          fourth floor      blue
# ..    ...               ...        ...                   ...       ...
# 343  P126       Andrew Choe 1988-01-03                   NaN    violet
# 344  P203     Krish Thakker 1965-09-26           third floor    yellow
# 345  P273     Jeonghan Yoon 2003-07-12          fourth floor      blue
# 346  P290  Ananya Malipeddi 1994-10-03           third floor    yellow
# 347  P233         Ifra Syed 1982-06-27          second floor       red
#
#     Skin_Color Hair_Color  Height  Age
# 0       indigo     orange     191   56
# ...

# %% [markdown]
# ## Q3) Finding the features of the culprit (38 PTS Total)
#
# Now that we have successfully cleaned all of our data, let's begin finding the features of the criminal. Take a moment to look at the **"Witnesses"** table. We do not necessarily want all the statements from every single witness.
#
# **NOTE:** Take a look at the structure of each statement. Notice how there are only a few variations of statements from the witnesses.

# %% [markdown]
# **TASK 3.1 (5 Points):** Find all witnesses who were near the crime scene.
# - First, load the `Witness.csv` file and assign it to a variable called **witness_df**.
# - Create a new DataFrame called **important_witnesses** that contains the ID and witness statements of those who were near the scene of the crime.
# - Display the new DataFrame when you are finished.
# - **HINT:** Look at the floor where the crime happened.

# %%
witness_df = pd.read_csv("Witness.csv")

important_witnesses = pd.merge(
    witness_df,
    profiles_df[["ID", "Location_during_crime"]],
    on="ID"
)

important_witnesses = important_witnesses[
    important_witnesses["Location_during_crime"] == "second floor"
][["ID", "Statement"]]

important_witnesses
# Out:
#        ID                                          Statement
# 13   P150  I saw someone with orange hair acting suspicious.
# 17   P075  I saw someone with orange hair acting suspicious.
# 21   P058   I saw someone with green eyes acting suspicious.
# 22   P157  I saw someone who looked 152 cm tall acting su...
# 23   P157  I saw someone who looked 152 cm tall acting su...
# ..    ...                                                ...
# 329  P077  I saw someone with orange eyes acting suspicious.
# 330  P168     I saw someone with red skin acting suspicious.
# 331  P168     I saw someone with red skin acting suspicious.
# 345  P145  I saw someone with orange eyes acting suspicious.
# 346  P145  I saw someone with orange eyes acting suspicious.
#
# [71 rows x 2 columns]

# %% [markdown]
# **TASK 3.2 (5 Points):** Find every potential eye color that the culprit could have.
#
#  - Put all the potential eye colors of the culprit in a list called **potential_eye_colors** and **display** it when you are done.
#  - **potential_eye_colors** should have **no duplicates**.

# %%
eye_statements = important_witnesses[
    important_witnesses["Statement"].str.contains("eyes", case=False, na=False)
]

potential_eye_colors = (
    eye_statements["Statement"]
    .str.extract(r"with (\w+) eyes", expand=False)
    .dropna()
    .unique()
    .tolist()
)

potential_eye_colors
# Out:
# ['green', 'orange', 'blue', 'violet']

# %% [markdown]
# **TASK 3.3 (5 Points):** Find every potential hair color that the culprit could have.
#
#  - Put all the potential hair colors of the culprit in a list called **potential_hair_colors** and **display** it when you are done.

# %%
# Write your code here.

# %% [markdown]
# **TASK 3.4 (5 Points):** Find every potential skin color that the culprit could have.
#
#  - Put all the potential skin colors of the culprit in a list called **potential_skin_colors** and display it when you are done.

# %%
# Write your code here.

# %% [markdown]
# **TASK 3.5 (10 Points):** Find the potential height of the culprit.
#
#  - Put the smallest and largest potential heights of the culprit in variables called **smallest_height** and **largest_height**, and display them when you are done.

# %%
# Write your code here.

# %% [markdown]
# **TASK 3.6 (8 Points):** Find the potential age of the culprit.
#
#  - Put the smallest and largest potential ages of the culprit in variables called **smallest_age** and **largest_age**, and display them when you are done.

# %%
# Write your code here.

# %% [markdown]
# ## Q4) Who owns the Ticket? (30 PTS Total)

# %% [markdown]
# **TASK 4.1 (2 Points):** Load the final DataFrames.
#
#
# Load **"Zichao's Magic Show.csv"** into a DataFrame called **show_df** and **"Interrogation_Statement.csv"** into a DataFrame called **interrogation_df**, respectively. Display them when you are done.

# %%
# Write your code here.

# %% [markdown]
# We're **so close** to figuring out the *last* and *final* clue needed to locate the culprit, but it looks like they are trying to beat us to it! What a devious criminal!
#
# The culprit must have **sabotaged** our data after **interrogation** because it looks so wonky with weird symbols.
#
# However, HQ informed us that our good friend and exemplar cryptanalyst **Alan Turing** has something to say to help us fix the data. **He encoded his message to keep it safe from the culprit.**
#
# **TASK 4.2 (10 Points):**
#
# Find what **Alan Turing** has to say:
# - Use **interrogation_df** to locate **Alan Turing's** message.
# - Put the message in a variable called **encoded_message** as a string. (**Exclude** any **quotation marks** within the statement.)
#  - **Print** the encoded message in the following format: {"Encoded Message:", encoded_message}
# - Figure out what the message says by taking a look at the numbers:
#  - A **single space** between numbers indicates a letter used to form a word.
#  - A **double space** between numbers indicates the start of a new word.
# - Store his decoded message in a variable called **decoded_message**.
# - Print **Alan Turing's** decoded message in the following format: {"Decoded Message:", decoded_message}
#
# **Hint:** Maybe [enumerating](https://docs.python.org/3/library/functions.html#enumerate) to map letters to numbers might help, along with using [ASCII values](https://docs.python.org/3/library/string.html).

# %%
# Write your code here.

# %% [markdown]
# **TASK 4.3 (10 Points):**
#
# **Restore** the interrogation statements to their original state after **following the decoded message from before**.
# - After restoration, make sure your modifications are updated in **interrogation_df** itself.
# - **Display** **interrogation_df** when you are done.

# %%
# Write your code here.

# %% [markdown]
# **TASK 4.4 (8 Points):** Create a column called **Ticket_Color** for **show_df** that displays the color of each ticket.
#
# Remember that there was a show ticket left at the crime scene. Take a second to look through **show_df**.
# - Try to find a way to identify the ticket color from the ticket number.
# - **Display** **show_df** when you are done.
#
# **HINT:** Examine **interrogation_df**; someone might have an idea.

# %%
# Write your code here.

# %% [markdown]
# ## Q5) Finding the culprit (12 PTS Total)
#
# The `iloc` function might be helpful. Have a look at: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html

# %% [markdown]
# **TASK 5.1 (10 Points):** Using all the **data compiled from before**, find a person who matches all the features from the profile.
#
# - Do not hardcode, or you will lose credit after all your hard work. 🥸
#
# - Put the name of the culprit in a variable called **culprit**.
# - Print the name of the culprit. (There is only one.)

# %%
# Write your code here.

# %% [markdown]
# **TASK 5.2 (2 Points):** Check whether your culprit is correct!
#
# **Interrogate** your culprit to see whether you got the correct person.

# %%
# Write your code here.

# %% [markdown]
# # GREAT WORK, DETECTIVE!! 🌻
